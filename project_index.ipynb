# %%
import pandas as pd

# %%
df= pd.read_csv('Traffic.csv')

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
df.tail()
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 5947  10:45:00 PM     9        Thursday        16          3         1
# 5948  11:00:00 PM     9        Thursday        11          0         1
# 5949  11:15:00 PM     9        Thursday        15          4         1
# 5950  11:30:00 PM     9        Thursday        16          5         0
# 5951  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 5947          36     56            normal
# 5948          30     42            normal
# 5949          25     45            normal
# 5950          27     48            normal
# 5951          15     33               low

# %%
df.sample(2)
# Out:
#             Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 2801  4:15:00 AM     8       Wednesday        66          3         1
# 273   8:15:00 PM    12        Thursday        84         15        12
#
#       TruckCount  Total Traffic Situation
# 2801          26     96            normal
# 273           16    127            normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               5952 non-null   object
#  1   Date               5952 non-null   int64
#  2   Day of the week    5952 non-null   object
#  3   CarCount           5952 non-null   int64
#  4   BikeCount          5952 non-null   int64
#  5   BusCount           5952 non-null   int64
#  6   TruckCount         5952 non-null   int64
#  7   Total              5952 non-null   int64
#  8   Traffic Situation  5952 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 418.6+ KB

# %%
df.describe()
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  5952.000000  5952.000000  5952.000000  5952.000000  5952.000000
# mean     16.000000    65.440692    12.161458    12.912970    18.646337
# std       8.945023    44.749335    11.537944    12.497736    10.973139
# min       1.000000     5.000000     0.000000     0.000000     0.000000
# 25%       8.000000    18.750000     3.000000     2.000000    10.000000
# 50%      16.000000    62.000000     9.000000    10.000000    18.000000
# 75%      24.000000   103.000000    19.000000    20.000000    27.000000
# max      31.000000   180.000000    70.000000    50.000000    60.000000
#
#              Total
# count  5952.000000
# mean    109.161458
# std      55.996312
# min      21.000000
# 25%      54.000000
# 50%     104.000000
# 75%     153.000000
# max     279.000000

# %%
df['Day of the week'].value_counts()
# Out:
# Day of the week
# Tuesday      960
# Wednesday    960
# Thursday     960
# Friday       768
# Saturday     768
# Sunday       768
# Monday       768
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['Time','Day of the week','Date']]
# Out:
#              Time Day of the week  Date
# 0     12:00:00 AM         Tuesday    10
# 1     12:15:00 AM         Tuesday    10
# 2     12:30:00 AM         Tuesday    10
# 3     12:45:00 AM         Tuesday    10
# 4      1:00:00 AM         Tuesday    10
# ...           ...             ...   ...
# 5947  10:45:00 PM        Thursday     9
# 5948  11:00:00 PM        Thursday     9
# 5949  11:15:00 PM        Thursday     9
# 5950  11:30:00 PM        Thursday     9
# 5951  11:45:00 PM        Thursday     9
#
# [5952 rows x 3 columns]

# %%
df.iloc[1:5]
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
df.loc[1:5,["Date",'Time']]
# Out:
#    Date         Time
# 1    10  12:15:00 AM
# 2    10  12:30:00 AM
# 3    10  12:45:00 AM
# 4    10   1:00:00 AM
# 5    10   1:15:00 AM

# %%
df.columns
# Out:
# Index(['Time', 'Date', 'Day of the week', 'CarCount', 'BikeCount', 'BusCount',
#        'TruckCount', 'Total', 'Traffic Situation'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5952, step=1)

# %%
df.query('Total > 250')
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 3303   9:45:00 AM    13          Friday       171         59        27
# 3307  10:45:00 AM    13          Friday       178         68        28
# 3308  11:00:00 AM    13          Friday       169         70        20
# 3311  11:45:00 AM    13          Friday       179         46        27
# 3315  12:45:00 PM    13          Friday       174         67        30
# 3318   1:30:00 PM    13          Friday       175         63        19
# 3319   1:45:00 PM    13          Friday       172         62        20
# 3321   2:15:00 PM    13          Friday       172         65        18
# 3974   9:30:00 AM    20          Friday       170         62        18
# 3976  10:00:00 AM    20          Friday       166         63        22
# 3986  12:30:00 PM    20          Friday       173         63        13
# 3991   1:45:00 PM    20          Friday       168         59        24
# 3993   2:15:00 PM    20          Friday       179         63        12
# 4646   9:30:00 AM    27          Friday       180         69        29
# 4648  10:00:00 AM    27          Friday       167         60        27
# 4650  10:30:00 AM    27          Friday       180         62        26
# 5319   9:45:00 AM     3          Friday       168         68        27
# 5333   1:15:00 PM     3          Friday       174         54        25
# 5340   3:00:00 PM     3          Friday       179         60        12
#
#       TruckCount  Total Traffic Situation
# 3303           3    260             heavy
# 3307           4    278             heavy
# 3308           3    262             heavy
# 3311           3    255             heavy
# 3315           1    272             heavy
# 3318           3    260             heavy
# 3319           2    256             heavy
# 3321           2    257             heavy
# 3974           2    252             heavy
# 3976           1    252             heavy
# 3986           2    251             heavy
# 3991           1    252             heavy
# 3993           2    256             heavy
# 4646           1    279             heavy
# 4648           3    257             heavy
# 4650           4    272             heavy
# 5319           2    265             heavy
# 5333           1    254             heavy
# 5340           0    251             heavy

# %%
 df = df.set_index(['Day of the week', "Time"])
 df.loc[('Monday','12:00:00 AM')]
# Out:
# <ipython-input-19-4865c352a2fe>:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[('Monday','12:00:00 AM')]
#                              Date  CarCount  BikeCount  BusCount  TruckCount  \
# Day of the week Time
# Monday          12:00:00 AM    16        11          2         2          39
#                 12:00:00 AM    23        15          1         0          37
#                 12:00:00 AM    30        14          2         0          33
#                 12:00:00 AM     6         9          2         0          27
#                 12:00:00 AM    16        18          4         1          28
#                 12:00:00 AM    23        13          2         1          17
#                 12:00:00 AM    30        13          3         1          12
#                 12:00:00 AM     6        11          3         0          26
#
#                              Total Traffic Situation
# Day of the week Time
# Monday          12:00:00 AM     54            normal
#                 12:00:00 AM     53            normal
#                 12:00:00 AM     49            normal
#                 12:00:00 AM     38            normal
#                 12:00:00 AM     51            normal
#                 12:00:00 AM     33               low
#                 12:00:00 AM     29               low
#                 12:00:00 AM     40            normal

# %%
df
# Out:
#                              Date  CarCount  BikeCount  BusCount  TruckCount  \
# Day of the week Time
# Tuesday         12:00:00 AM    10        13          2         2          24
#                 12:15:00 AM    10        14          1         1          36
#                 12:30:00 AM    10        10          2         2          32
#                 12:45:00 AM    10        10          2         2          36
#                 1:00:00 AM     10        11          2         1          34
# ...                           ...       ...        ...       ...         ...
# Thursday        10:45:00 PM     9        16          3         1          36
#                 11:00:00 PM     9        11          0         1          30
#                 11:15:00 PM     9        15          4         1          25
#                 11:30:00 PM     9        16          5         0          27
#                 11:45:00 PM     9        14          3         1          15
#
#                              Total Traffic Situation
# Day of the week Time
# Tuesday         12:00:00 AM     41            normal
#                 12:15:00 AM     52            normal
#                 12:30:00 AM     46            normal
#                 12:45:00 AM     50            normal
#                 1:00:00 AM      48            normal
# ...                            ...               ...
# Thursday        10:45:00 PM     56            normal
#                 11:00:00 PM     42            normal
#                 11:15:00 PM     45            normal
#                 11:30:00 PM     48            normal
#                 11:45:00 PM     33               low
#
# [5952 rows x 7 columns]

# %%
df.reset_index(inplace=True)

# %%
df.reset_index(inplace=False)
# Out:
#       level_0  index Day of the week         Time  Date  CarCount  BikeCount  \
# 0           0      0         Tuesday  12:00:00 AM    10        13          2
# 1           1      1         Tuesday  12:15:00 AM    10        14          1
# 2           2      2         Tuesday  12:30:00 AM    10        10          2
# 3           3      3         Tuesday  12:45:00 AM    10        10          2
# 4           4      4         Tuesday   1:00:00 AM    10        11          2
# ...       ...    ...             ...          ...   ...       ...        ...
# 5947     5947   5947        Thursday  10:45:00 PM     9        16          3
# 5948     5948   5948        Thursday  11:00:00 PM     9        11          0
# 5949     5949   5949        Thursday  11:15:00 PM     9        15          4
# 5950     5950   5950        Thursday  11:30:00 PM     9        16          5
# 5951     5951   5951        Thursday  11:45:00 PM     9        14          3
#
#       BusCount  TruckCount  Total Traffic Situation
# 0            2          24     41            normal
# 1            1          36     52            normal
# 2            2          32     46            normal
# 3            2          36     50            normal
# 4            1          34     48            normal
# ...        ...         ...    ...               ...
# 5947         1          36     56            normal
# 5948         1          30     42            normal
# 5949         1          25     45            normal
# 5950         0          27     48            normal
# 5951         1          15     33               low
#
# [5952 rows x 11 columns]

# %%
df
# Out:
#      Day of the week         Time  Date  CarCount  BikeCount  BusCount  \
# 0            Tuesday  12:00:00 AM    10        13          2         2
# 1            Tuesday  12:15:00 AM    10        14          1         1
# 2            Tuesday  12:30:00 AM    10        10          2         2
# 3            Tuesday  12:45:00 AM    10        10          2         2
# 4            Tuesday   1:00:00 AM    10        11          2         1
# ...              ...          ...   ...       ...        ...       ...
# 5947        Thursday  10:45:00 PM     9        16          3         1
# 5948        Thursday  11:00:00 PM     9        11          0         1
# 5949        Thursday  11:15:00 PM     9        15          4         1
# 5950        Thursday  11:30:00 PM     9        16          5         0
# 5951        Thursday  11:45:00 PM     9        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0             24     41            normal
# 1             36     52            normal
# 2             32     46            normal
# 3             36     50            normal
# 4             34     48            normal
# ...          ...    ...               ...
# 5947          36     56            normal
# 5948          30     42            normal
# 5949          25     45            normal
# 5950          27     48            normal
# 5951          15     33               low
#
# [5952 rows x 9 columns]

# %%
grouped_data = df.groupby(['Day of the week'])['Total'].sum()
print(grouped_data)
# Out:
# Day of the week
# Friday        81626
# Monday        83576
# Saturday      84542
# Sunday        84201
# Thursday     105074
# Tuesday      104882
# Wednesday    105828
# Name: Total, dtype: int64
