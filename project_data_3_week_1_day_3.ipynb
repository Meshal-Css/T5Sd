# %% [markdown]
# <a href="https://colab.research.google.com/github/Meshal-Css/T5Sd/blob/main/project_data_3_week_1_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Traffic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               5952 non-null   object
#  1   Date               5952 non-null   int64
#  2   Day of the week    5952 non-null   object
#  3   CarCount           5952 non-null   int64
#  4   BikeCount          5952 non-null   int64
#  5   BusCount           5952 non-null   int64
#  6   TruckCount         5952 non-null   int64
#  7   Total              5952 non-null   int64
#  8   Traffic Situation  5952 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 418.6+ KB

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
df.isnull().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  5952.000000  5952.000000  5952.000000  5952.000000  5952.000000
# mean     16.000000    65.440692    12.161458    12.912970    18.646337
# std       8.945023    44.749335    11.537944    12.497736    10.973139
# min       1.000000     5.000000     0.000000     0.000000     0.000000
# 25%       8.000000    18.750000     3.000000     2.000000    10.000000
# 50%      16.000000    62.000000     9.000000    10.000000    18.000000
# 75%      24.000000   103.000000    19.000000    20.000000    27.000000
# max      31.000000   180.000000    70.000000    50.000000    60.000000
#
#              Total
# count  5952.000000
# mean    109.161458
# std      55.996312
# min      21.000000
# 25%      54.000000
# 50%     104.000000
# 75%     153.000000
# max     279.000000

# %%
df["CarCount"].min()
# Out:
# 5

# %%
numerical_columns = df[['CarCount',"BikeCount","BusCount","TruckCount","Total"]]
correlation_matrix = numerical_columns.corr()
print(correlation_matrix)
# Out:
#             CarCount  BikeCount  BusCount  TruckCount     Total
# CarCount    1.000000   0.708243  0.658417   -0.615043  0.971507
# BikeCount   0.708243   1.000000  0.577671   -0.607720  0.781879
# BusCount    0.658417   0.577671  1.000000   -0.558372  0.758970
# TruckCount -0.615043  -0.607720 -0.558372    1.000000 -0.545390
# Total       0.971507   0.781879  0.758970   -0.545390  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True)
plt.title("correlation_matrix")
plt.show()

# %%
df['CarCount']
# Out:
# 0       13
# 1       14
# 2       10
# 3       10
# 4       11
#         ..
# 5947    16
# 5948    11
# 5949    15
# 5950    16
# 5951    14
# Name: CarCount, Length: 5952, dtype: int64

# %%
df[['CarCount','BikeCount']]
# Out:
#       CarCount  BikeCount
# 0           13          2
# 1           14          1
# 2           10          2
# 3           10          2
# 4           11          2
# ...        ...        ...
# 5947        16          3
# 5948        11          0
# 5949        15          4
# 5950        16          5
# 5951        14          3
#
# [5952 rows x 2 columns]

# %%
df.iloc[60]
# Out:
# Time                 3:00:00 PM
# Date                         10
# Day of the week         Tuesday
# CarCount                      5
# BikeCount                    13
# BusCount                      4
# TruckCount                   20
# Total                        42
# Traffic Situation        normal
# Name: 60, dtype: object

# %%
df.iloc[10:30]
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 10  2:30:00 AM    10         Tuesday        15          2         0
# 11  2:45:00 AM    10         Tuesday         5          2         0
# 12  3:00:00 AM    10         Tuesday         9          1         0
# 13  3:15:00 AM    10         Tuesday         8          0         2
# 14  3:30:00 AM    10         Tuesday         7          0         0
# 15  3:45:00 AM    10         Tuesday        10          1         2
# 16  4:00:00 AM    10         Tuesday        82          7         3
# 17  4:15:00 AM    10         Tuesday        71          3         0
# 18  4:30:00 AM    10         Tuesday        89         10         2
# 19  4:45:00 AM    10         Tuesday        77          3         0
# 20  5:00:00 AM    10         Tuesday        90          2         0
# 21  5:15:00 AM    10         Tuesday        84          1         7
# 22  5:30:00 AM    10         Tuesday        88          8         6
# ...

# %%
df.set_index(['Day of the week','Total'], inplace = True)
df.loc[('Tuesday',55)]
# Out:
# <ipython-input-16-b54385aa50b7>:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[('Tuesday',55)]
#                               Time  Date  CarCount  BikeCount  BusCount  \
# Day of the week Total
# Tuesday         55      2:30:00 AM    10        15          2         0
#                 55     11:00:00 PM    10        11          2         2
#                 55     12:15:00 AM    10        49          0         3
#                 55     12:30:00 AM    10        46          0         3
#                 55      1:45:00 AM    10        42          4         4
#                 55      2:00:00 AM    24        19          2         1
#                 55      1:15:00 PM    31         6         24        12
#                 55     12:00:00 PM     7        20          6         6
#
#                        TruckCount Traffic Situation
# Day of the week Total
# Tuesday         55             38            normal
# ...

# %%
df.query('Total >= 50')
# Out:
#                               Time  Date  CarCount  BikeCount  BusCount  \
# Day of the week Total
# Tuesday         52     12:15:00 AM    10        14          1         1
#                 50     12:45:00 AM    10        10          2         2
#                 56      1:15:00 AM    10        15          1         1
#                 55      2:30:00 AM    10        15          2         0
#                 51      3:45:00 AM    10        10          1         2
# ...                            ...   ...       ...        ...       ...
# Thursday        162     9:00:00 PM     9       107         13        14
#                 142     9:15:00 PM     9        91          5        12
#                 164     9:30:00 PM     9       106         18        13
#                 149     9:45:00 PM     9       107         14        10
#                 56     10:45:00 PM     9        16          3         1
#
#                        TruckCount Traffic Situation
# Day of the week Total
# ...

# %%
df.set_index(['CarCount','BikeCount'], inplace = True)
df.head()
# Out:
#                            Time  Date  BusCount  TruckCount Traffic Situation
# CarCount BikeCount
# 13       2          12:00:00 AM    10         2          24            normal
# 14       1          12:15:00 AM    10         1          36            normal
# 10       2          12:30:00 AM    10         2          32            normal
#          2          12:45:00 AM    10         2          36            normal
# 11       2           1:00:00 AM    10         1          34            normal

# %%
df.reset_index(inplace = True)
df.head()
# Out:
#    CarCount  BikeCount         Time  Date  BusCount  TruckCount  \
# 0        13          2  12:00:00 AM    10         2          24
# 1        14          1  12:15:00 AM    10         1          36
# 2        10          2  12:30:00 AM    10         2          32
# 3        10          2  12:45:00 AM    10         2          36
# 4        11          2   1:00:00 AM    10         1          34
#
#   Traffic Situation
# 0            normal
# 1            normal
# 2            normal
# 3            normal
# 4            normal

# %%
grouped_data = df.groupby(['CarCount','BikeCount'])
grouped_data.head()
# Out:
#       CarCount  BikeCount         Time  Date  BusCount  TruckCount  \
# 0           13          2  12:00:00 AM    10         2          24
# 1           14          1  12:15:00 AM    10         1          36
# 2           10          2  12:30:00 AM    10         2          32
# 3           10          2  12:45:00 AM    10         2          36
# 4           11          2   1:00:00 AM    10         1          34
# ...        ...        ...          ...   ...       ...         ...
# 5939        61         14   8:45:00 PM     9        10           5
# 5940       107         13   9:00:00 PM     9        14          28
# 5941        91          5   9:15:00 PM     9        12          34
# 5942       106         18   9:30:00 PM     9        13          27
# 5943       107         14   9:45:00 PM     9        10          18
#
#      Traffic Situation
# 0               normal
# 1               normal
# 2               normal
# 3               normal
# 4               normal
# ...
